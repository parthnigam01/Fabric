# %% [markdown]
# # 🚀 PySpark Interview Practice — Basic to 5 Years Data Engineering Level
#
# ---
#
# | Detail | Info |
# |--------|------|
# | **Prepared For** | Parth Nigam — Liberty Mutual |
# | **Date** | September 12, 2026 |
# | **Skill Level** | Basic → Intermediate → Advanced (DE 5 Yrs) |
# | **Total Questions** | 70+ Practice Activities |
#
# ---
#
# ### 📌 Instructions
# - Each section provides a **sample DataFrame** — use it to solve the activities below it.
# - **Do NOT look at answers** — try each activity independently.
# - Run the setup cells first before attempting questions.
# - Cells marked 🔥 are **high-frequency interview questions**.
# - Cells marked ⚡ are **advanced / 4–5 yr level**.
#
# ---
#
# ### 📂 Sections
# 1. Environment Setup
# 2. DataFrame Basics
# 3. Filtering, Selecting & Sorting
# 4. Aggregations & GroupBy
# 5. Joins
# 6. Window Functions
# 7. String & Date Functions
# 8. Null Handling
# 9. Schema & Data Types
# 10. User Defined Functions (UDFs)
# 11. File I/O — Read & Write
# 12. Performance & Optimization
# 13. Real-World ETL Scenarios
# 14. PySpark SQL
# 15. Bonus — Tricky Interview Questions

# %% [markdown]
# ## ⚙️ Section 1 — Environment Setup

# %%
# Run this cell first — Install PySpark if not already installed
# !pip install pyspark

# %%
from pyspark.sql import SparkSession
from pyspark.sql import functions as F
from pyspark.sql.types import *
from pyspark.sql.window import Window

spark = SparkSession.builder \
    .appName('PySpark_Interview_Practice') \
    .master('local[*]') \
    .config('spark.sql.shuffle.partitions', '4') \
    .getOrCreate()

spark.sparkContext.setLogLevel('ERROR')
print('✅ SparkSession ready:', spark.version)

# %% [markdown]
# ## 📦 Section 2 — DataFrame Basics  *(0–6 Months)*

# %%
# ── SAMPLE DATAFRAME ────────────────────────────────────────────────────
employee_data = [
    (1,  'Parth',   'Engineering',  95000,  5, 'India',   '2021-03-15'),
    (2,  'Ananya',  'Engineering',  87000,  3, 'India',   '2023-07-01'),
    (3,  'Raj',     'Marketing',    72000,  4, 'India',   '2022-01-20'),
    (4,  'Sarah',   'Marketing',    68000,  2, 'US',      '2024-05-10'),
    (5,  'Tom',     'Finance',      91000,  6, 'US',      '2020-11-30'),
    (6,  'Priya',   'Finance',      83000,  4, 'India',   '2022-08-14'),
    (7,  'James',   'Engineering',  None,   7, 'UK',      '2019-06-01'),
    (8,  'Meera',   'HR',           61000,  1, 'India',   '2025-02-28'),
    (9,  'Chris',   'HR',           58000,  2, 'US',      '2024-09-01'),
    (10, 'Divya',   'Finance',      77000,  3, 'India',   '2023-03-17'),
]

emp_schema = StructType([
    StructField('emp_id',     IntegerType(), True),
    StructField('name',       StringType(),  True),
    StructField('department', StringType(),  True),
    StructField('salary',     IntegerType(), True),
    StructField('experience', IntegerType(), True),
    StructField('country',    StringType(),  True),
    StructField('join_date',  StringType(),  True),
])

emp_df = spark.createDataFrame(employee_data, schema=emp_schema)
emp_df.show()

# %% [markdown]
# ### 🟢 Q1 — Display the schema of `emp_df`. What is the data type of `salary`?

# %%
# Your code here

# %% [markdown]
# ### 🟢 Q2 — How many rows and columns does `emp_df` have? Find it programmatically.

# %%
# Your code here

# %% [markdown]
# ### 🟢 Q3 — Display only the first 5 rows. Then display the last 3 rows.

# %%
# Your code here

# %% [markdown]
# ### 🟢 Q4 — Select only `name`, `department`, and `salary` columns.

# %%
# Your code here

# %% [markdown]
# ### 🟢 Q5 — Rename column `experience` to `years_of_exp`.

# %%
# Your code here

# %% [markdown]
# ### 🟢 Q6 — Add a new column `annual_bonus` = 10% of salary.

# %%
# Your code here

# %% [markdown]
# ### 🟢 Q7 — Drop the `country` column from `emp_df`.

# %%
# Your code here

# %% [markdown]
# ## 🔍 Section 3 — Filtering, Selecting & Sorting  *(6 Months – 1 Year)*

# %% [markdown]
# ### 🟡 Q8 — Filter employees with salary greater than 80,000.

# %%
# Your code here

# %% [markdown]
# ### 🟡 Q9 — Filter employees from `Engineering` OR `Finance` departments.

# %%
# Your code here

# %% [markdown]
# ### 🟡 Q10 🔥 — Filter employees with salary between 70,000 and 90,000 AND from India.

# %%
# Your code here

# %% [markdown]
# ### 🟡 Q11 — Sort employees by salary in descending order. Then sort by department ASC and salary DESC.

# %%
# Your code here

# %% [markdown]
# ### 🟡 Q12 — Find distinct countries present in the dataset.

# %%
# Your code here

# %% [markdown]
# ### 🟡 Q13 🔥 — Filter employees whose name starts with the letter `P` or `A`.

# %%
# Your code here

# %% [markdown]
# ## 📊 Section 4 — Aggregations & GroupBy  *(1 – 2 Years)*

# %% [markdown]
# ### 🟡 Q14 🔥 — For each department, find: total employees, average salary, min salary, max salary.

# %%
# Your code here

# %% [markdown]
# ### 🟡 Q15 — Find the total salary expense per country.

# %%
# Your code here

# %% [markdown]
# ### 🟡 Q16 🔥 — Find departments where average salary is above 75,000.

# %%
# Your code here

# %% [markdown]
# ### 🟡 Q17 — Count how many employees are from each country per department. (Group by two columns)

# %%
# Your code here

# %% [markdown]
# ### 🟡 Q18 — Use `agg()` with multiple aggregation functions in a single call on `emp_df`.

# %%
# Your code here

# %% [markdown]
# ## 🔗 Section 5 — Joins  *(1 – 2 Years)*

# %%
# ── SAMPLE DATAFRAMES FOR JOINS ─────────────────────────────────────────
dept_data = [
    ('Engineering', 'D001', 'Alice Manager',   500000),
    ('Marketing',   'D002', 'Bob Lead',        300000),
    ('Finance',     'D003', 'Carol Head',      400000),
    ('Legal',       'D004', 'David Director',  200000),   # No employees in emp_df
]
dept_df = spark.createDataFrame(dept_data,
    ['department', 'dept_id', 'manager', 'budget'])

project_data = [
    (1, 'Project Alpha',  1),
    (2, 'Project Beta',   2),
    (3, 'Project Gamma',  1),
    (4, 'Project Delta',  5),
    (5, 'Project Zeta',   99),  # emp_id 99 does not exist
]
project_df = spark.createDataFrame(project_data,
    ['project_id', 'project_name', 'lead_emp_id'])

dept_df.show()
project_df.show()

# %% [markdown]
# ### 🟡 Q19 🔥 — Perform an INNER JOIN between `emp_df` and `dept_df` on `department`. Show `name`, `department`, `manager`, `budget`.

# %%
# Your code here

# %% [markdown]
# ### 🟡 Q20 🔥 — Perform a LEFT JOIN to keep all employees even if their department is not in `dept_df`.

# %%
# Your code here

# %% [markdown]
# ### 🟡 Q21 — Perform a FULL OUTER JOIN between `emp_df` and `dept_df`. Identify which departments have no employees.

# %%
# Your code here

# %% [markdown]
# ### 🟡 Q22 🔥 — Use a SEMI JOIN to find employees who are assigned to at least one project (using `project_df`).

# %%
# Your code here

# %% [markdown]
# ### 🟡 Q23 — Use an ANTI JOIN to find employees who have NO assigned projects.

# %%
# Your code here

# %% [markdown]
# ### 🔴 Q24 ⚡ — Perform a BROADCAST JOIN between `emp_df` (large) and `dept_df` (small). Why is this important in production?

# %%
# Your code here

# %% [markdown]
# ## 🪟 Section 6 — Window Functions  *(2 – 3 Years)*

# %% [markdown]
# ### 🔴 Q25 🔥 — Assign a RANK to each employee within their department based on salary (highest = rank 1).

# %%
# Your code here

# %% [markdown]
# ### 🔴 Q26 🔥 — Find the TOP 1 highest-paid employee in each department using window functions (NOT groupBy).

# %%
# Your code here

# %% [markdown]
# ### 🔴 Q27 — Calculate the RUNNING TOTAL (cumulative sum) of salary ordered by `emp_id`.

# %%
# Your code here

# %% [markdown]
# ### 🔴 Q28 — For each employee, show their salary AND the average salary of their department side-by-side.

# %%
# Your code here

# %% [markdown]
# ### 🔴 Q29 ⚡ — Use `LAG()` and `LEAD()` to show each employee's previous and next salary (ordered by emp_id).

# %%
# Your code here

# %% [markdown]
# ### 🔴 Q30 ⚡ — What is the difference between `rank()`, `dense_rank()`, and `row_number()`? Demonstrate all three on `emp_df` partitioned by department.

# %%
# Your code here

# %% [markdown]
# ## 🧵 Section 7 — String & Date Functions  *(1 – 3 Years)*

# %% [markdown]
# ### 🟡 Q31 — Convert `name` column to UPPERCASE. Add a column with the length of each name.

# %%
# Your code here

# %% [markdown]
# ### 🟡 Q32 — Concatenate `name` and `department` into a single column like: `Parth | Engineering`.

# %%
# Your code here

# %% [markdown]
# ### 🟡 Q33 🔥 — Cast `join_date` (string) to `DateType`. Then extract the year, month, and day into separate columns.

# %%
# Your code here

# %% [markdown]
# ### 🟡 Q34 — Calculate the number of years each employee has been with the company (from `join_date` to today).

# %%
# Your code here

# %% [markdown]
# ### 🟡 Q35 — Filter employees who joined in the year 2022 or later.

# %%
# Your code here

# %% [markdown]
# ## ❓ Section 8 — Null Handling  *(1 – 2 Years)*

# %% [markdown]
# ### 🟡 Q36 🔥 — Find all employees with a NULL salary. How many are there?

# %%
# Your code here

# %% [markdown]
# ### 🟡 Q37 — Fill NULL salaries with the department average salary.

# %%
# Your code here

# %% [markdown]
# ### 🟡 Q38 — Use `coalesce()` to replace NULL salary with 0 and NULL name with 'Unknown'.

# %%
# Your code here

# %% [markdown]
# ### 🟡 Q39 — Drop rows where ANY column has a null value. Then drop rows only where `salary` is null.

# %%
# Your code here

# %% [markdown]
# ## 🗂️ Section 9 — Schema & Data Types  *(2 – 3 Years)*

# %%
# ── SAMPLE: Nested / Complex Data ────────────────────────────────────────
raw_data = [
    (1, '{"city": "Mumbai",  "zip": "400001"}', ['Python', 'PySpark', 'SQL'],    '95000.50'),
    (2, '{"city": "Delhi",   "zip": "110001"}', ['SQL', 'Tableau'],              '87000.00'),
    (3, '{"city": "Chennai", "zip": "600001"}', ['Python', 'Airflow', 'Kafka'],  '72000.75'),
    (4, '{"city": "Pune",    "zip": "411001"}', ['Java', 'Spark'],               None),
]
raw_schema = StructType([
    StructField('id',       IntegerType(), True),
    StructField('address',  StringType(),  True),  # JSON string
    StructField('skills',   ArrayType(StringType()), True),
    StructField('salary',   StringType(),  True),  # stored as string — needs cast
])
raw_df = spark.createDataFrame(raw_data, schema=raw_schema)
raw_df.show(truncate=False)

# %% [markdown]
# ### 🔴 Q40 🔥 — Cast the `salary` column from StringType to DoubleType.

# %%
# Your code here

# %% [markdown]
# ### 🔴 Q41 ⚡ — Parse the `address` JSON string column and extract `city` and `zip` as separate columns.

# %%
# Your code here

# %% [markdown]
# ### 🔴 Q42 ⚡ — Use `explode()` to convert the `skills` array column into individual rows.

# %%
# Your code here

# %% [markdown]
# ### 🔴 Q43 — Filter employees who have 'PySpark' in their `skills` array.

# %%
# Your code here

# %% [markdown]
# ## 🛠️ Section 10 — User Defined Functions (UDFs)  *(2 – 3 Years)*

# %% [markdown]
# ### 🔴 Q44 🔥 — Write a UDF that categorizes salary as:
# - `< 65,000` → `'Low'`
# - `65,000 – 85,000` → `'Mid'`
# - `> 85,000` → `'High'`
#
# Apply it to `emp_df` as a new column `salary_band`.

# %%
# Your code here

# %% [markdown]
# ### 🔴 Q45 ⚡ — Rewrite the above UDF using `F.when().otherwise()` (without UDF).
# **Why is this preferred over a Python UDF in production?**

# %%
# Your code here

# %% [markdown]
# ### 🔴 Q46 ⚡ — Create a Pandas UDF (vectorized UDF) that calculates `salary * 1.15` for each row.

# %%
# Your code here

# %% [markdown]
# ## 💾 Section 11 — File I/O — Read & Write  *(2 – 3 Years)*

# %% [markdown]
# ### 🔴 Q47 🔥 — Write `emp_df` to a Parquet file at path `./output/employees/`. Then read it back and verify row count.

# %%
# Your code here

# %% [markdown]
# ### 🔴 Q48 — Write `emp_df` partitioned by `department` and `country` to `./output/emp_partitioned/`. How does partitioning affect read performance?

# %%
# Your code here

# %% [markdown]
# ### 🔴 Q49 ⚡ — Write `emp_df` to a single CSV file (not multiple part files). What function do you use and what are the tradeoffs?

# %%
# Your code here

# %% [markdown]
# ### 🔴 Q50 ⚡ — Write with `mode='overwrite'` vs `mode='append'`. When would you use each in a pipeline?

# %%
# Your code here  (also write a short comment explaining each mode)

# %% [markdown]
# ## ⚡ Section 12 — Performance & Optimization  *(3 – 5 Years)*

# %% [markdown]
# ### 🔴 Q51 ⚡ — How many partitions does `emp_df` have?
# Repartition it to 8 partitions by `department`. Then coalesce to 2 partitions.
# **What is the difference between `repartition()` and `coalesce()`?**

# %%
# Your code here

# %% [markdown]
# ### 🔴 Q52 ⚡ — Cache `emp_df` and demonstrate the performance difference between the first and second action.
# **When should you cache vs persist? What storage levels are available?**

# %%
# Your code here

# %% [markdown]
# ### 🔴 Q53 ⚡ — Explain and demonstrate the difference between:
# - **Narrow transformation** (e.g., `filter`, `map`)
# - **Wide transformation** (e.g., `groupBy`, `join`)
#
# Use `explain()` on a query to view the physical plan.

# %%
# Your code here

# %% [markdown]
# ### 🔴 Q54 ⚡ — What is a data skew problem? Create a skewed dataset and demonstrate how to handle it using salting technique.

# %%
# ── SAMPLE: Skewed Dataset ────────────────────────────────────────────────
skewed_data = [(i, 'Engineering') for i in range(1, 951)] + \
              [(i, 'Finance')     for i in range(951, 976)] + \
              [(i, 'HR')          for i in range(976, 1001)]
skewed_df = spark.createDataFrame(skewed_data, ['id', 'department'])

# Activity: Show the skew, then handle it using salting
# Your code here

# %% [markdown]
# ### 🔴 Q55 ⚡ — Use `explain(True)` to view the query plan of a join between `emp_df` and `dept_df`. Identify if a BroadcastHashJoin or SortMergeJoin is used.

# %%
# Your code here

# %% [markdown]
# ## 🏭 Section 13 — Real-World ETL Scenarios  *(3 – 5 Years)*

# %%
# ── SAMPLE: Transactions Dataset ─────────────────────────────────────────
transactions_data = [
    (1,  101, 'purchase',  1500.00, '2026-01-05 10:30:00'),
    (2,  102, 'purchase',   800.50, '2026-01-06 11:00:00'),
    (3,  101, 'refund',    -200.00, '2026-01-07 09:15:00'),
    (4,  103, 'purchase',  3200.00, '2026-01-07 14:00:00'),
    (5,  101, 'purchase',   950.00, '2026-02-01 08:45:00'),
    (6,  102, 'purchase',  1100.00, '2026-02-03 16:20:00'),
    (7,  104, 'purchase',   450.75, '2026-02-10 12:00:00'),
    (8,  101, 'purchase',  2200.00, '2026-03-15 10:00:00'),
    (9,  103, 'refund',    -500.00, '2026-03-16 11:30:00'),
    (10, 101, 'purchase',  1800.00, '2026-03-20 09:00:00'),
    (2,  102, 'purchase',   800.50, '2026-01-06 11:00:00'),   # duplicate of row 2
]
txn_schema = StructType([
    StructField('txn_id',     IntegerType(), True),
    StructField('customer_id',IntegerType(), True),
    StructField('type',       StringType(),  True),
    StructField('amount',     DoubleType(),  True),
    StructField('txn_ts',     StringType(),  True),
])
txn_df = spark.createDataFrame(transactions_data, schema=txn_schema)
txn_df.show(truncate=False)

# %% [markdown]
# ### 🔴 Q56 🔥 — Remove duplicate transactions from `txn_df`. Keep only the latest record per `txn_id`.

# %%
# Your code here

# %% [markdown]
# ### 🔴 Q57 — Calculate the total net spend per customer (purchases - refunds). Sort by highest spender.

# %%
# Your code here

# %% [markdown]
# ### 🔴 Q58 ⚡ — Identify customers whose spending INCREASED month-over-month. Use window functions.

# %%
# Your code here

# %% [markdown]
# ### 🔴 Q59 ⚡ — Implement a **Slowly Changing Dimension (SCD Type 2)** logic: given an `updates_df`, merge changes into `emp_df` tracking history with `effective_start`, `effective_end`, and `is_current` columns.

# %%
# ── SAMPLE: Updates ───────────────────────────────────────────────────────
updates_data = [
    (1, 'Parth',  'Engineering', 105000, 5, 'India', '2026-09-01'),  # salary change
    (3, 'Raj',    'Finance',      78000, 4, 'India', '2026-09-01'),  # dept change
]
updates_df = spark.createDataFrame(updates_data,
    ['emp_id','name','department','salary','experience','country','join_date'])

# Your SCD Type 2 logic here

# %% [markdown]
# ### 🔴 Q60 ⚡ — Write a data quality check function that validates: (a) no null emp_ids, (b) salary > 0, (c) join_date is not in the future. Return a summary report.

# %%
# Your code here

# %% [markdown]
# ## 🗃️ Section 14 — PySpark SQL  *(2 – 4 Years)*

# %%
# Register DataFrames as temp views
emp_df.createOrReplaceTempView('employees')
dept_df.createOrReplaceTempView('departments')
txn_df.createOrReplaceTempView('transactions')
print('✅ Temp views registered: employees, departments, transactions')

# %% [markdown]
# ### 🟡 Q61 — Using Spark SQL, write a query to find the top 2 highest-paid employees per department.

# %%
# spark.sql(""" YOUR SQL HERE """)

# %% [markdown]
# ### 🟡 Q62 🔥 — Write a SQL query using a CTE to find employees earning more than their department's average salary.

# %%
# spark.sql(""" YOUR SQL HERE """)

# %% [markdown]
# ### 🟡 Q63 ⚡ — Write SQL to pivot the employee count per department across countries (rows = department, columns = country).

# %%
# spark.sql(""" YOUR SQL HERE """)

# %% [markdown]
# ### 🟡 Q64 — Create a **Global Temp View** of `txn_df` and query it from a different session context.

# %%
# Your code here

# %% [markdown]
# ## 🎯 Section 15 — Bonus: Tricky Interview Questions  *(All Levels)*

# %% [markdown]
# ### 🔴 Q65 ⚡ — What is **lazy evaluation** in PySpark?
# Demonstrate it by creating a chain of transformations and show that nothing executes until an **action** is called.

# %%
# Your code here

# %% [markdown]
# ### 🔴 Q66 🔥 — You have two DataFrames with the SAME column name `id`. How do you handle ambiguous column references after a join?
# Demonstrate the issue and fix it.

# %%
# Your code here

# %% [markdown]
# ### 🔴 Q67 ⚡ — What is the difference between `collect()`, `take(n)`, and `first()`? When should you AVOID using `collect()`?

# %%
# Your code here  (demonstrate each + add comment on when to avoid collect)

# %% [markdown]
# ### 🔴 Q68 ⚡ — Implement an **incremental load** pattern:
# Given a `new_records_df` and an existing `target_df`, upsert (update existing + insert new) using only PySpark DataFrame API (no Delta Lake).

# %%
# ── SAMPLE DATA ───────────────────────────────────────────────────────────
existing_data = [(1,'Parth',95000),(2,'Ananya',87000),(3,'Raj',72000)]
new_data      = [(2,'Ananya',92000),(4,'Sarah',68000)]   # emp 2 updated, emp 4 is new

existing_df = spark.createDataFrame(existing_data, ['emp_id','name','salary'])
new_df      = spark.createDataFrame(new_data,      ['emp_id','name','salary'])

# Activity: Upsert new_df into existing_df
# Your code here

# %% [markdown]
# ### 🔴 Q69 ⚡ — Generate a column with a **monotonically increasing unique ID** for each row in `emp_df`. What are the limitations of `monotonically_increasing_id()`?

# %%
# Your code here

# %% [markdown]
# ### 🔴 Q70 ⚡ — Given the `transactions_data`, create a **session window** grouping:
# Group consecutive transactions per customer where the gap between transactions is less than 30 days. Calculate session-level total spend.

# %%
# Your code here

# %% [markdown]
# ---
#
# ## ✅ Practice Complete!
#
# | Level | Questions | Colour |
# |-------|-----------|--------|
# | Beginner (0–1 yr) | Q1–Q18 | 🟢 Green |
# | Intermediate (1–3 yrs) | Q19–Q46 | 🟡 Yellow |
# | Advanced / DE 5yr | Q47–Q70 | 🔴 Red / ⚡ Lightning |
#
# ### 📌 Key Topics to Revise Before Interview
# - Window Functions (`rank`, `dense_rank`, `lag`, `lead`, `row_number`)
# - Join types & Broadcast join
# - Repartition vs Coalesce
# - Cache vs Persist
# - Lazy Evaluation & DAG
# - SCD Type 2
# - Data Skew & Salting
# - UDF vs Pandas UDF vs `F.when()`
# - Incremental Load patterns
# - Parquet partitioning strategy
#
# ---
# *Good Luck, Parth! 🚀 — Liberty Mutual Data Engineering*
